# %%
import os
import cv2
import numpy as np
from glob import glob
from scipy.io import loadmat
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras import backend as K
from keras.utils import io_utils
from tensorflow.python.platform import tf_logging as logging
from google.colab import drive

drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/collage/segmentation')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_DIR = "/content/drive/MyDrive/Colab Notebooks/collage/segmentation/data/rawdata/humanparsing"
train_num = 30
val_num = 10

all_images = sorted(glob(os.path.join(DATA_DIR, "val/Images/*")))
all_masks = sorted(glob(os.path.join(DATA_DIR, "val/Human/*")))

train_images, train_masks = all_images[:train_num], all_masks[:train_num]
val_images, val_masks = all_images[train_num:train_num+val_num], all_masks[train_num:train_num+val_num]

# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (0.17.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)

# %%
IMAGE_SIZE = 512
BATCH_SIZE = 8
NUM_CLASSES = 1
import tensorflow_addons as tfa

def read_image(image_path, mask=False):
  image = tf.io.read_file(image_path)
  image = tf.image.decode_png(image, channels=3)
  image.set_shape([None, None, 3])
  image = tf.image.resize(images=image, size=[IMAGE_SIZE, IMAGE_SIZE])
  if not mask:
      image = image / 255
  return image

def load_data(image_list, mask_list):
  image = read_image(image_list)
  mask = read_image(mask_list, mask=True)
  return image, mask

def random_crop(input_image, real_image, size):
  stacked_image = tf.stack([input_image, real_image], axis=0)
  cropped_image = tf.image.random_crop(
      stacked_image, size=[2, size, size, 3])
  img,msk = cropped_image[0], cropped_image[1]
  return img,msk

def augment(input_image, input_mask):

  if tf.random.uniform(()) > 0.3:
      ratio = tf.random.uniform(shape=[],minval=400, maxval=440, dtype=tf.int32)
      input_image, input_mask = random_crop(input_image, input_mask, ratio)
      input_image = tf.image.resize(input_image, (IMAGE_SIZE, IMAGE_SIZE))
      input_mask = tf.image.resize(input_mask, (IMAGE_SIZE, IMAGE_SIZE))

  input_image = tf.image.random_brightness(input_image, 0.2)

  saturation_factor = tf.random.uniform((),0,2)
  input_image = tf.image.adjust_saturation(input_image, saturation_factor)

  if tf.random.uniform(()) > 0.5:
      input_image = tf.image.flip_left_right(input_image)
      input_mask = tf.image.flip_left_right(input_mask)

  rot_factor = tf.cast(tf.random.uniform(shape=[],minval=-6, maxval=6, dtype=tf.int32), tf.float32)
  angle = np.pi/(12*6) *rot_factor
  input_image = tfa.image.rotate(input_image, angle)
  input_mask = tfa.image.rotate(input_mask, angle)

  return input_image, input_mask

def cast_mask(input_image, input_mask):
  
  input_mask = tf.math.reduce_sum(input_mask, axis=2)
  input_mask = input_mask[..., tf.newaxis]
  input_mask = tf.cast(input_mask>0, dtype=tf.float32)
  return input_image,input_mask

def data_generator(image_list, mask_list, augument=True):
  dataset = tf.data.Dataset.from_tensor_slices((image_list, mask_list))
  dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
  if augument:
    dataset = dataset.map(augment)
  dataset = dataset.map(cast_mask)

  dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
  return dataset

train_dataset = data_generator(train_images, train_masks)
print("Train Dataset:", train_dataset)

val_dataset = data_generator(val_images, val_masks, augument=False)
print("Validation Dataset:", val_dataset)
# Out:
# Train Dataset: <BatchDataset element_spec=(TensorSpec(shape=(8, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(8, 512, 512, 1), dtype=tf.float32, name=None))>
# Validation Dataset: <BatchDataset element_spec=(TensorSpec(shape=(8, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(8, 512, 512, 1), dtype=tf.float32, name=None))>

# %%
_, axes = plt.subplots(nrows=2, ncols=2, figsize=(10,10))

idx = 9
img = read_image(train_images[idx])
msk = read_image(train_masks[idx], mask=True)

augmented_img, augmented_msk = augment(img,msk)


# axes[0][0].imshow(np.squeeze(np.where(np.sum(msk, axis=2)>0, 1,0)))
axes[0][0].imshow(np.squeeze(msk))
axes[0][1].imshow(img)
axes[1][0].imshow(np.squeeze(augmented_msk))
axes[1][1].imshow(augmented_img)
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from tensorflow.keras.applications.vgg16 import VGG16

def fcn_up(x, skip, num_filters, upsize):
  x = layers.Conv2D(num_filters, 3, strides=1, padding="same")(x)
  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)
  x = layers.Conv2DTranspose(num_filters, (upsize,upsize), strides=upsize, padding='same')(x)
  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)
  if skip is not None:
    return keras.layers.Add()([x, skip])
  else : 
    return x

def FCN_8(image_size, num_classes):
  vgg_model = VGG16(input_shape = (512,512,3), weights = 'imagenet', include_top=False)
  vgg_model.trainable = False
  layer_names  = ['block3_pool', 'block4_pool', 'block5_pool']
  skip_layers = [vgg_model.get_layer(name).output for name in layer_names]
  fcn_model = tf.keras.Model(inputs=vgg_model.input, outputs=skip_layers)

  inputs = keras.Input(shape=(image_size, image_size, 3))
  skips = fcn_model(inputs)

  vgg_32_layer = skips[-1]
  vgg_16_layer = skips[-2]
  vgg_8_layer = skips[-3]
  x = fcn_up(vgg_32_layer, vgg_16_layer, 512,2)
  x = fcn_up(x, vgg_8_layer, 256,2)
  x = fcn_up(x, None, 32,8)

  model_output = layers.Conv2D(1, kernel_size=(1, 1), padding="same", activation='sigmoid')(x)

  return keras.Model(inputs, model_output)

# %%
class unfreeze_layers_reduce_lr(tf.keras.callbacks.ReduceLROnPlateau):

  def __init__(self,
               monitor='val_loss',
               factor=0.1,
               patience=10,
               verbose=0,
               mode='auto',
               min_delta=1e-4,
               cooldown=0,
               min_lr=0,
               freezed=False,
               **kwargs):
      super().__init__(monitor, factor, patience, verbose, mode, min_delta, cooldown, min_lr)
      self.freezed = False


  def on_epoch_end(self, epoch, logs=None):
    logs = logs or {}
    logs['lr'] = K.get_value(self.model.optimizer.lr)
    current = logs.get(self.monitor)
    if current is None:
      logging.warning('Learning rate reduction is conditioned on metric `%s` '
                      'which is not available. Available metrics are: %s',
                      self.monitor, ','.join(list(logs.keys())))
    else:
      if self.in_cooldown():
        self.cooldown_counter -= 1
        self.wait = 0

      if self.monitor_op(current, self.best):
        self.best = current
        self.wait = 0

      elif not self.in_cooldown():
        self.wait += 1
        if self.wait >= self.patience:
          
          if not self.freezed:
            for layer in self.model.layers:
                      layer.trainable = True
            self.freezed=True
            old_lr = K.get_value(self.model.optimizer.lr)
            new_lr = old_lr * 0.1
            K.set_value(self.model.optimizer.lr, new_lr)
            io_utils.print_msg(
                    f'\nEpoch {epoch +1}: '
                    f'Unfreezing backbone layers and reducing learning rate to {new_lr}')
            self.cooldown_counter = self.cooldown
            self.wait = 0

          else:
            old_lr = K.get_value(self.model.optimizer.lr)
            if old_lr > np.float32(self.min_lr):
              new_lr = old_lr * self.factor
              new_lr = max(new_lr, self.min_lr)
              K.set_value(self.model.optimizer.lr, new_lr)
              if self.verbose > 0:
                io_utils.print_msg(
                    f'\nEpoch {epoch +1}: '
                    f'ReduceLROnPlateau reducing learning rate to {new_lr}.')
              self.cooldown_counter = self.cooldown
              self.wait = 0

class CustomSaver(keras.callbacks.Callback):
  def __init__(self, save_path, save_name, frequency):
    self.save_path = save_path
    self.save_name = save_name
    self.frequency = frequency

  def on_epoch_end(self, epoch, logs={}):
      if (epoch+1) % self.frequency == 0 :
          name = self.save_path + self.save_name + f'{epoch+1:03d}.h5'
          self.model.save(name)
          io_utils.print_msg(
                    f'\nEpoch {epoch + 1}:'
                    f'saving model to {name}')

model_path, model_name = './model_weight/callback_test/', 'test_weight_epoch_'
model_path_best = './model_weight/callback_test/test_weight_best.h5'
csv_name = './model_weight/callback_test/test_weight.csv'

custom_saver = CustomSaver(model_path, model_name ,frequency=10)
reduce_lr = unfreeze_layers_reduce_lr(monitor='val_loss', factor=0.5, patience=2, verbose=1, mode='min', min_delta=1e-4, cooldown=0, min_lr=0,)
save_best = tf.keras.callbacks.ModelCheckpoint(model_path_best, monitor='val_loss', verbose=0, save_best_only=True)
write_log = tf.keras.callbacks.CSVLogger(csv_name, separator=',', append=True)

cb_list = [custom_saver, reduce_lr, save_best, write_log]

# %%
model = FCN_8(image_size=IMAGE_SIZE, num_classes=NUM_CLASSES)
loss = keras.losses.BinaryCrossentropy()
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.01),
    loss=loss,
    metrics=["accuracy",tf.keras.metrics.BinaryIoU()],
  )
# model.summary()

# %%
history = model.fit(train_dataset, validation_data=val_dataset,
                    callbacks=cb_list,
                    epochs=100)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 22s 2s/step - loss: 0.8067 - accuracy: 0.5295 - binary_io_u: 0.3522 - val_loss: 5.4358 - val_accuracy: 0.4859 - val_binary_io_u: 0.2667 - lr: 0.0100
# Epoch 2/100
# 3/3 [==============================] - 1s 273ms/step - loss: 0.6068 - accuracy: 0.6730 - binary_io_u: 0.4857 - val_loss: 20.1202 - val_accuracy: 0.4718 - val_binary_io_u: 0.2415 - lr: 0.0100
# Epoch 3/100
# 3/3 [==============================] - ETA: 0s - loss: 0.5379 - accuracy: 0.7346 - binary_io_u: 0.5689
# Epoch 3: Unfreezing backbone layers and reducing learning rate to 0.0009999999776482583
# 3/3 [==============================] - 1s 280ms/step - loss: 0.5379 - accuracy: 0.7346 - binary_io_u: 0.5689 - val_loss: 29.2987 - val_accuracy: 0.4845 - val_binary_io_u: 0.2564 - lr: 0.0100
# Epoch 4/100
# 3/3 [==============================] - 1s 289ms/step - loss: 0.4962 - accuracy: 0.7737 - binary_io_u: 0.6234 - val_loss: 16.3384 - val_accuracy: 0.4899 - val_binary_io_u: 0.2628 - lr: 1.0000e-03
# Epoch 5/100
# 3/3 [==============================] - ETA: 0s - loss: 0.4820 - accuracy: 0.7863 - binary_io_u: 0.6402
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0004999999655410647.
# 3/3 [==============================] - 1s 280ms/step - loss: 0.4820 - accuracy: 0.7863 - binary_io_u: 0.6402 - val_loss: 12.2982 - val_accuracy: 0.4950 - val_binary_io_u: 0.2690 - lr: 1.0000e-03
# Epoch 6/100
# 3/3 [==============================] - 1s 277ms/step - loss: 0.4854 - accuracy: 0.7805 - binary_io_u: 0.6346 - val_loss: 8.8267 - val_accuracy: 0.5027 - val_binary_io_u: 0.2784 - lr: 5.0000e-04
# Epoch 7/100
# 3/3 [==============================] - ETA: 0s - loss: 0.4649 - accuracy: 0.7984 - binary_io_u: 0.6576
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00024999998277053237.
# 3/3 [==============================] - 1s 276ms/step - loss: 0.4649 - accuracy: 0.7984 - binary_io_u: 0.6576 - val_loss: 6.7108 - val_accuracy: 0.5115 - val_binary_io_u: 0.2890 - lr: 5.0000e-04
# Epoch 8/100
# 3/3 [==============================] - 1s 490ms/step - loss: 0.4695 - accuracy: 0.7888 - binary_io_u: 0.6449 - val_loss: 5.1306 - val_accuracy: 0.5211 - val_binary_io_u: 0.3005 - lr: 2.5000e-04
# Epoch 9/100
# 3/3 [==============================] - 1s 467ms/step - loss: 0.4695 - accuracy: 0.7911 - binary_io_u: 0.6489 - val_loss: 4.0871 - val_accuracy: 0.5305 - val_binary_io_u: 0.3118 - lr: 2.5000e-04
# Epoch 10/100
# 3/3 [==============================] - ETA: 0s - loss: 0.4606 - accuracy: 0.7954 - binary_io_u: 0.6546
# Epoch 10:saving model to ./model_weight/callback_test/test_weight_epoch_010.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.4606 - accuracy: 0.7954 - binary_io_u: 0.6546 - val_loss: 3.2833 - val_accuracy: 0.5412 - val_binary_io_u: 0.3248 - lr: 2.5000e-04
# Epoch 11/100
# 3/3 [==============================] - 1s 466ms/step - loss: 0.4488 - accuracy: 0.8065 - binary_io_u: 0.6702 - val_loss: 2.6165 - val_accuracy: 0.5563 - val_binary_io_u: 0.3431 - lr: 2.5000e-04
# Epoch 12/100
# 3/3 [==============================] - 1s 466ms/step - loss: 0.4534 - accuracy: 0.8005 - binary_io_u: 0.6622 - val_loss: 2.1240 - val_accuracy: 0.5741 - val_binary_io_u: 0.3649 - lr: 2.5000e-04
# Epoch 13/100
# 3/3 [==============================] - 1s 471ms/step - loss: 0.4502 - accuracy: 0.8034 - binary_io_u: 0.6651 - val_loss: 1.7638 - val_accuracy: 0.5936 - val_binary_io_u: 0.3889 - lr: 2.5000e-04
# Epoch 14/100
# 3/3 [==============================] - 1s 468ms/step - loss: 0.4415 - accuracy: 0.8106 - binary_io_u: 0.6758 - val_loss: 1.4989 - val_accuracy: 0.6129 - val_binary_io_u: 0.4129 - lr: 2.5000e-04
# Epoch 15/100
# 3/3 [==============================] - 1s 486ms/step - loss: 0.4502 - accuracy: 0.7983 - binary_io_u: 0.6610 - val_loss: 1.2688 - val_accuracy: 0.6345 - val_binary_io_u: 0.4401 - lr: 2.5000e-04
# Epoch 16/100
# 3/3 [==============================] - 1s 479ms/step - loss: 0.4356 - accuracy: 0.8114 - binary_io_u: 0.6778 - val_loss: 1.0776 - val_accuracy: 0.6603 - val_binary_io_u: 0.4732 - lr: 2.5000e-04
# Epoch 17/100
# 3/3 [==============================] - 1s 540ms/step - loss: 0.4493 - accuracy: 0.8018 - binary_io_u: 0.6646 - val_loss: 0.9353 - val_accuracy: 0.6865 - val_binary_io_u: 0.5074 - lr: 2.5000e-04
# Epoch 18/100
# 3/3 [==============================] - 3s 469ms/step - loss: 0.4378 - accuracy: 0.8073 - binary_io_u: 0.6720 - val_loss: 0.8370 - val_accuracy: 0.7018 - val_binary_io_u: 0.5277 - lr: 2.5000e-04
# Epoch 19/100
# 3/3 [==============================] - 1s 470ms/step - loss: 0.4292 - accuracy: 0.8112 - binary_io_u: 0.6792 - val_loss: 0.7659 - val_accuracy: 0.7134 - val_binary_io_u: 0.5432 - lr: 2.5000e-04
# Epoch 20/100
# 3/3 [==============================] - ETA: 0s - loss: 0.4202 - accuracy: 0.8178 - binary_io_u: 0.6882
# Epoch 20:saving model to ./model_weight/callback_test/test_weight_epoch_020.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.4202 - accuracy: 0.8178 - binary_io_u: 0.6882 - val_loss: 0.7060 - val_accuracy: 0.7254 - val_binary_io_u: 0.5594 - lr: 2.5000e-04
# Epoch 21/100
# 3/3 [==============================] - 1s 459ms/step - loss: 0.4095 - accuracy: 0.8299 - binary_io_u: 0.7056 - val_loss: 0.6540 - val_accuracy: 0.7367 - val_binary_io_u: 0.5749 - lr: 2.5000e-04
# Epoch 22/100
# 3/3 [==============================] - 2s 626ms/step - loss: 0.4203 - accuracy: 0.8212 - binary_io_u: 0.6910 - val_loss: 0.6136 - val_accuracy: 0.7485 - val_binary_io_u: 0.5912 - lr: 2.5000e-04
# Epoch 23/100
# 3/3 [==============================] - 1s 471ms/step - loss: 0.3985 - accuracy: 0.8359 - binary_io_u: 0.7137 - val_loss: 0.5765 - val_accuracy: 0.7611 - val_binary_io_u: 0.6088 - lr: 2.5000e-04
# Epoch 24/100
# 3/3 [==============================] - 1s 461ms/step - loss: 0.4054 - accuracy: 0.8285 - binary_io_u: 0.7035 - val_loss: 0.5367 - val_accuracy: 0.7747 - val_binary_io_u: 0.6281 - lr: 2.5000e-04
# Epoch 25/100
# 3/3 [==============================] - 1s 488ms/step - loss: 0.3949 - accuracy: 0.8363 - binary_io_u: 0.7146 - val_loss: 0.5064 - val_accuracy: 0.7855 - val_binary_io_u: 0.6437 - lr: 2.5000e-04
# Epoch 26/100
# 3/3 [==============================] - 2s 468ms/step - loss: 0.4061 - accuracy: 0.8263 - binary_io_u: 0.6992 - val_loss: 0.4811 - val_accuracy: 0.7957 - val_binary_io_u: 0.6584 - lr: 2.5000e-04
# Epoch 27/100
# 3/3 [==============================] - 1s 475ms/step - loss: 0.3966 - accuracy: 0.8345 - binary_io_u: 0.7122 - val_loss: 0.4607 - val_accuracy: 0.8045 - val_binary_io_u: 0.6713 - lr: 2.5000e-04
# Epoch 28/100
# 3/3 [==============================] - 1s 467ms/step - loss: 0.4176 - accuracy: 0.8187 - binary_io_u: 0.6898 - val_loss: 0.4472 - val_accuracy: 0.8105 - val_binary_io_u: 0.6800 - lr: 2.5000e-04
# Epoch 29/100
# 3/3 [==============================] - 1s 473ms/step - loss: 0.3923 - accuracy: 0.8346 - binary_io_u: 0.7125 - val_loss: 0.4352 - val_accuracy: 0.8171 - val_binary_io_u: 0.6898 - lr: 2.5000e-04
# Epoch 30/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3954 - accuracy: 0.8326 - binary_io_u: 0.7084
# Epoch 30:saving model to ./model_weight/callback_test/test_weight_epoch_030.h5
# 3/3 [==============================] - 2s 647ms/step - loss: 0.3954 - accuracy: 0.8326 - binary_io_u: 0.7084 - val_loss: 0.4270 - val_accuracy: 0.8226 - val_binary_io_u: 0.6979 - lr: 2.5000e-04
# Epoch 31/100
# 3/3 [==============================] - 1s 465ms/step - loss: 0.3752 - accuracy: 0.8467 - binary_io_u: 0.7301 - val_loss: 0.4201 - val_accuracy: 0.8276 - val_binary_io_u: 0.7054 - lr: 2.5000e-04
# Epoch 32/100
# 3/3 [==============================] - 1s 466ms/step - loss: 0.3768 - accuracy: 0.8429 - binary_io_u: 0.7255 - val_loss: 0.4135 - val_accuracy: 0.8321 - val_binary_io_u: 0.7122 - lr: 2.5000e-04
# Epoch 33/100
# 3/3 [==============================] - 1s 466ms/step - loss: 0.3782 - accuracy: 0.8439 - binary_io_u: 0.7269 - val_loss: 0.4099 - val_accuracy: 0.8339 - val_binary_io_u: 0.7150 - lr: 2.5000e-04
# Epoch 34/100
# 3/3 [==============================] - 2s 493ms/step - loss: 0.3766 - accuracy: 0.8420 - binary_io_u: 0.7224 - val_loss: 0.4080 - val_accuracy: 0.8346 - val_binary_io_u: 0.7160 - lr: 2.5000e-04
# Epoch 35/100
# 3/3 [==============================] - 1s 471ms/step - loss: 0.3642 - accuracy: 0.8509 - binary_io_u: 0.7373 - val_loss: 0.4044 - val_accuracy: 0.8363 - val_binary_io_u: 0.7186 - lr: 2.5000e-04
# Epoch 36/100
# 3/3 [==============================] - 1s 486ms/step - loss: 0.3699 - accuracy: 0.8470 - binary_io_u: 0.7318 - val_loss: 0.4007 - val_accuracy: 0.8390 - val_binary_io_u: 0.7226 - lr: 2.5000e-04
# Epoch 37/100
# 3/3 [==============================] - 1s 473ms/step - loss: 0.3763 - accuracy: 0.8421 - binary_io_u: 0.7244 - val_loss: 0.3995 - val_accuracy: 0.8398 - val_binary_io_u: 0.7239 - lr: 2.5000e-04
# Epoch 38/100
# 3/3 [==============================] - 1s 290ms/step - loss: 0.3546 - accuracy: 0.8539 - binary_io_u: 0.7415 - val_loss: 0.4009 - val_accuracy: 0.8410 - val_binary_io_u: 0.7255 - lr: 2.5000e-04
# Epoch 39/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3550 - accuracy: 0.8541 - binary_io_u: 0.7413
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.00012499999138526618.
# 3/3 [==============================] - 1s 281ms/step - loss: 0.3550 - accuracy: 0.8541 - binary_io_u: 0.7413 - val_loss: 0.4043 - val_accuracy: 0.8398 - val_binary_io_u: 0.7235 - lr: 2.5000e-04
# Epoch 40/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3584 - accuracy: 0.8511 - binary_io_u: 0.7370
# Epoch 40:saving model to ./model_weight/callback_test/test_weight_epoch_040.h5
# 3/3 [==============================] - 1s 459ms/step - loss: 0.3584 - accuracy: 0.8511 - binary_io_u: 0.7370 - val_loss: 0.4063 - val_accuracy: 0.8389 - val_binary_io_u: 0.7219 - lr: 1.2500e-04
# Epoch 41/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3508 - accuracy: 0.8563 - binary_io_u: 0.7458
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.249999569263309e-05.
# 3/3 [==============================] - 1s 282ms/step - loss: 0.3508 - accuracy: 0.8563 - binary_io_u: 0.7458 - val_loss: 0.4093 - val_accuracy: 0.8375 - val_binary_io_u: 0.7196 - lr: 1.2500e-04
# Epoch 42/100
# 3/3 [==============================] - 1s 273ms/step - loss: 0.3541 - accuracy: 0.8505 - binary_io_u: 0.7369 - val_loss: 0.4095 - val_accuracy: 0.8373 - val_binary_io_u: 0.7193 - lr: 6.2500e-05
# Epoch 43/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3506 - accuracy: 0.8547 - binary_io_u: 0.7430
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.1249997846316546e-05.
# 3/3 [==============================] - 1s 304ms/step - loss: 0.3506 - accuracy: 0.8547 - binary_io_u: 0.7430 - val_loss: 0.4083 - val_accuracy: 0.8376 - val_binary_io_u: 0.7197 - lr: 6.2500e-05
# Epoch 44/100
# 3/3 [==============================] - 1s 275ms/step - loss: 0.3368 - accuracy: 0.8650 - binary_io_u: 0.7576 - val_loss: 0.4069 - val_accuracy: 0.8380 - val_binary_io_u: 0.7203 - lr: 3.1250e-05
# Epoch 45/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3364 - accuracy: 0.8651 - binary_io_u: 0.7589
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.5624998923158273e-05.
# 3/3 [==============================] - 1s 279ms/step - loss: 0.3364 - accuracy: 0.8651 - binary_io_u: 0.7589 - val_loss: 0.4057 - val_accuracy: 0.8383 - val_binary_io_u: 0.7207 - lr: 3.1250e-05
# Epoch 46/100
# 3/3 [==============================] - 1s 283ms/step - loss: 0.3405 - accuracy: 0.8622 - binary_io_u: 0.7537 - val_loss: 0.4044 - val_accuracy: 0.8388 - val_binary_io_u: 0.7214 - lr: 1.5625e-05
# Epoch 47/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3290 - accuracy: 0.8685 - binary_io_u: 0.7644
# Epoch 47: ReduceLROnPlateau reducing learning rate to 7.812499461579137e-06.
# 3/3 [==============================] - 1s 293ms/step - loss: 0.3290 - accuracy: 0.8685 - binary_io_u: 0.7644 - val_loss: 0.4034 - val_accuracy: 0.8391 - val_binary_io_u: 0.7218 - lr: 1.5625e-05
# Epoch 48/100
# 3/3 [==============================] - 1s 298ms/step - loss: 0.3473 - accuracy: 0.8595 - binary_io_u: 0.7503 - val_loss: 0.4022 - val_accuracy: 0.8394 - val_binary_io_u: 0.7223 - lr: 7.8125e-06
# Epoch 49/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3489 - accuracy: 0.8560 - binary_io_u: 0.7447
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.906249730789568e-06.
# 3/3 [==============================] - 1s 279ms/step - loss: 0.3489 - accuracy: 0.8560 - binary_io_u: 0.7447 - val_loss: 0.4010 - val_accuracy: 0.8397 - val_binary_io_u: 0.7227 - lr: 7.8125e-06
# Epoch 50/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3409 - accuracy: 0.8629 - binary_io_u: 0.7561
# Epoch 50:saving model to ./model_weight/callback_test/test_weight_epoch_050.h5
# 3/3 [==============================] - 2s 681ms/step - loss: 0.3409 - accuracy: 0.8629 - binary_io_u: 0.7561 - val_loss: 0.3999 - val_accuracy: 0.8400 - val_binary_io_u: 0.7231 - lr: 3.9062e-06
# Epoch 51/100
# 3/3 [==============================] - 2s 858ms/step - loss: 0.3500 - accuracy: 0.8578 - binary_io_u: 0.7476 - val_loss: 0.3986 - val_accuracy: 0.8403 - val_binary_io_u: 0.7236 - lr: 3.9062e-06
# Epoch 52/100
# 3/3 [==============================] - 1s 474ms/step - loss: 0.3467 - accuracy: 0.8560 - binary_io_u: 0.7454 - val_loss: 0.3974 - val_accuracy: 0.8406 - val_binary_io_u: 0.7241 - lr: 3.9062e-06
# Epoch 53/100
# 3/3 [==============================] - 1s 454ms/step - loss: 0.3360 - accuracy: 0.8652 - binary_io_u: 0.7600 - val_loss: 0.3963 - val_accuracy: 0.8409 - val_binary_io_u: 0.7246 - lr: 3.9062e-06
# Epoch 54/100
# 3/3 [==============================] - 1s 465ms/step - loss: 0.3474 - accuracy: 0.8583 - binary_io_u: 0.7470 - val_loss: 0.3951 - val_accuracy: 0.8412 - val_binary_io_u: 0.7251 - lr: 3.9062e-06
# Epoch 55/100
# 3/3 [==============================] - 2s 480ms/step - loss: 0.3510 - accuracy: 0.8548 - binary_io_u: 0.7436 - val_loss: 0.3941 - val_accuracy: 0.8414 - val_binary_io_u: 0.7253 - lr: 3.9062e-06
# Epoch 56/100
# 3/3 [==============================] - 1s 472ms/step - loss: 0.3473 - accuracy: 0.8554 - binary_io_u: 0.7441 - val_loss: 0.3931 - val_accuracy: 0.8416 - val_binary_io_u: 0.7256 - lr: 3.9062e-06
# Epoch 57/100
# 3/3 [==============================] - 1s 479ms/step - loss: 0.3401 - accuracy: 0.8623 - binary_io_u: 0.7548 - val_loss: 0.3920 - val_accuracy: 0.8419 - val_binary_io_u: 0.7260 - lr: 3.9062e-06
# Epoch 58/100
# 3/3 [==============================] - 1s 462ms/step - loss: 0.3382 - accuracy: 0.8614 - binary_io_u: 0.7528 - val_loss: 0.3910 - val_accuracy: 0.8421 - val_binary_io_u: 0.7263 - lr: 3.9062e-06
# Epoch 59/100
# 3/3 [==============================] - 1s 470ms/step - loss: 0.3412 - accuracy: 0.8608 - binary_io_u: 0.7524 - val_loss: 0.3900 - val_accuracy: 0.8423 - val_binary_io_u: 0.7266 - lr: 3.9062e-06
# Epoch 60/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3454 - accuracy: 0.8582 - binary_io_u: 0.7483
# Epoch 60:saving model to ./model_weight/callback_test/test_weight_epoch_060.h5
# 3/3 [==============================] - 2s 664ms/step - loss: 0.3454 - accuracy: 0.8582 - binary_io_u: 0.7483 - val_loss: 0.3890 - val_accuracy: 0.8425 - val_binary_io_u: 0.7269 - lr: 3.9062e-06
# Epoch 61/100
# 3/3 [==============================] - 1s 482ms/step - loss: 0.3477 - accuracy: 0.8556 - binary_io_u: 0.7454 - val_loss: 0.3881 - val_accuracy: 0.8426 - val_binary_io_u: 0.7272 - lr: 3.9062e-06
# Epoch 62/100
# 3/3 [==============================] - 1s 484ms/step - loss: 0.3547 - accuracy: 0.8512 - binary_io_u: 0.7377 - val_loss: 0.3872 - val_accuracy: 0.8428 - val_binary_io_u: 0.7274 - lr: 3.9062e-06
# Epoch 63/100
# 3/3 [==============================] - 2s 459ms/step - loss: 0.3362 - accuracy: 0.8643 - binary_io_u: 0.7578 - val_loss: 0.3862 - val_accuracy: 0.8431 - val_binary_io_u: 0.7278 - lr: 3.9062e-06
# Epoch 64/100
# 3/3 [==============================] - 1s 480ms/step - loss: 0.3439 - accuracy: 0.8572 - binary_io_u: 0.7470 - val_loss: 0.3853 - val_accuracy: 0.8432 - val_binary_io_u: 0.7281 - lr: 3.9062e-06
# Epoch 65/100
# 3/3 [==============================] - 1s 495ms/step - loss: 0.3386 - accuracy: 0.8639 - binary_io_u: 0.7579 - val_loss: 0.3844 - val_accuracy: 0.8434 - val_binary_io_u: 0.7283 - lr: 3.9062e-06
# Epoch 66/100
# 3/3 [==============================] - 3s 493ms/step - loss: 0.3420 - accuracy: 0.8615 - binary_io_u: 0.7529 - val_loss: 0.3834 - val_accuracy: 0.8437 - val_binary_io_u: 0.7287 - lr: 3.9062e-06
# Epoch 67/100
# 3/3 [==============================] - 1s 465ms/step - loss: 0.3433 - accuracy: 0.8584 - binary_io_u: 0.7473 - val_loss: 0.3825 - val_accuracy: 0.8439 - val_binary_io_u: 0.7291 - lr: 3.9062e-06
# Epoch 68/100
# 3/3 [==============================] - 1s 477ms/step - loss: 0.3575 - accuracy: 0.8488 - binary_io_u: 0.7339 - val_loss: 0.3817 - val_accuracy: 0.8440 - val_binary_io_u: 0.7293 - lr: 3.9062e-06
# Epoch 69/100
# 3/3 [==============================] - 1s 463ms/step - loss: 0.3440 - accuracy: 0.8586 - binary_io_u: 0.7481 - val_loss: 0.3808 - val_accuracy: 0.8443 - val_binary_io_u: 0.7297 - lr: 3.9062e-06
# Epoch 70/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3372 - accuracy: 0.8648 - binary_io_u: 0.7584
# Epoch 70:saving model to ./model_weight/callback_test/test_weight_epoch_070.h5
# 3/3 [==============================] - 2s 639ms/step - loss: 0.3372 - accuracy: 0.8648 - binary_io_u: 0.7584 - val_loss: 0.3799 - val_accuracy: 0.8445 - val_binary_io_u: 0.7300 - lr: 3.9062e-06
# Epoch 71/100
# 3/3 [==============================] - 2s 456ms/step - loss: 0.3346 - accuracy: 0.8653 - binary_io_u: 0.7586 - val_loss: 0.3791 - val_accuracy: 0.8447 - val_binary_io_u: 0.7303 - lr: 3.9062e-06
# Epoch 72/100
# 3/3 [==============================] - 1s 485ms/step - loss: 0.3394 - accuracy: 0.8618 - binary_io_u: 0.7527 - val_loss: 0.3783 - val_accuracy: 0.8449 - val_binary_io_u: 0.7306 - lr: 3.9062e-06
# Epoch 73/100
# 3/3 [==============================] - 1s 470ms/step - loss: 0.3571 - accuracy: 0.8512 - binary_io_u: 0.7381 - val_loss: 0.3775 - val_accuracy: 0.8451 - val_binary_io_u: 0.7309 - lr: 3.9062e-06
# Epoch 74/100
# 3/3 [==============================] - 2s 465ms/step - loss: 0.3504 - accuracy: 0.8551 - binary_io_u: 0.7430 - val_loss: 0.3768 - val_accuracy: 0.8453 - val_binary_io_u: 0.7312 - lr: 3.9062e-06
# Epoch 75/100
# 3/3 [==============================] - 1s 479ms/step - loss: 0.3470 - accuracy: 0.8568 - binary_io_u: 0.7464 - val_loss: 0.3761 - val_accuracy: 0.8454 - val_binary_io_u: 0.7313 - lr: 3.9062e-06
# Epoch 76/100
# 3/3 [==============================] - 1s 476ms/step - loss: 0.3453 - accuracy: 0.8591 - binary_io_u: 0.7504 - val_loss: 0.3755 - val_accuracy: 0.8455 - val_binary_io_u: 0.7316 - lr: 3.9062e-06
# Epoch 77/100
# 3/3 [==============================] - 1s 472ms/step - loss: 0.3531 - accuracy: 0.8549 - binary_io_u: 0.7423 - val_loss: 0.3746 - val_accuracy: 0.8457 - val_binary_io_u: 0.7319 - lr: 3.9062e-06
# Epoch 78/100
# 3/3 [==============================] - 2s 468ms/step - loss: 0.3460 - accuracy: 0.8573 - binary_io_u: 0.7476 - val_loss: 0.3739 - val_accuracy: 0.8459 - val_binary_io_u: 0.7321 - lr: 3.9062e-06
# Epoch 79/100
# 3/3 [==============================] - 1s 490ms/step - loss: 0.3443 - accuracy: 0.8589 - binary_io_u: 0.7500 - val_loss: 0.3733 - val_accuracy: 0.8460 - val_binary_io_u: 0.7323 - lr: 3.9062e-06
# Epoch 80/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3411 - accuracy: 0.8609 - binary_io_u: 0.7532
# Epoch 80:saving model to ./model_weight/callback_test/test_weight_epoch_080.h5
# 3/3 [==============================] - 2s 673ms/step - loss: 0.3411 - accuracy: 0.8609 - binary_io_u: 0.7532 - val_loss: 0.3726 - val_accuracy: 0.8461 - val_binary_io_u: 0.7325 - lr: 3.9062e-06
# Epoch 81/100
# 3/3 [==============================] - 1s 486ms/step - loss: 0.3444 - accuracy: 0.8582 - binary_io_u: 0.7479 - val_loss: 0.3719 - val_accuracy: 0.8463 - val_binary_io_u: 0.7328 - lr: 3.9062e-06
# Epoch 82/100
# 3/3 [==============================] - 3s 674ms/step - loss: 0.3589 - accuracy: 0.8482 - binary_io_u: 0.7341 - val_loss: 0.3712 - val_accuracy: 0.8465 - val_binary_io_u: 0.7331 - lr: 3.9062e-06
# Epoch 83/100
# 3/3 [==============================] - 1s 480ms/step - loss: 0.3444 - accuracy: 0.8582 - binary_io_u: 0.7483 - val_loss: 0.3706 - val_accuracy: 0.8466 - val_binary_io_u: 0.7333 - lr: 3.9062e-06
# Epoch 84/100
# 3/3 [==============================] - 1s 502ms/step - loss: 0.3390 - accuracy: 0.8635 - binary_io_u: 0.7565 - val_loss: 0.3700 - val_accuracy: 0.8467 - val_binary_io_u: 0.7335 - lr: 3.9062e-06
# Epoch 85/100
# 3/3 [==============================] - 1s 467ms/step - loss: 0.3432 - accuracy: 0.8602 - binary_io_u: 0.7508 - val_loss: 0.3692 - val_accuracy: 0.8469 - val_binary_io_u: 0.7338 - lr: 3.9062e-06
# Epoch 86/100
# 3/3 [==============================] - 1s 474ms/step - loss: 0.3379 - accuracy: 0.8630 - binary_io_u: 0.7559 - val_loss: 0.3686 - val_accuracy: 0.8470 - val_binary_io_u: 0.7340 - lr: 3.9062e-06
# Epoch 87/100
# 3/3 [==============================] - 1s 476ms/step - loss: 0.3477 - accuracy: 0.8574 - binary_io_u: 0.7480 - val_loss: 0.3680 - val_accuracy: 0.8472 - val_binary_io_u: 0.7342 - lr: 3.9062e-06
# Epoch 88/100
# 3/3 [==============================] - 2s 466ms/step - loss: 0.3370 - accuracy: 0.8645 - binary_io_u: 0.7579 - val_loss: 0.3674 - val_accuracy: 0.8474 - val_binary_io_u: 0.7345 - lr: 3.9062e-06
# Epoch 89/100
# 3/3 [==============================] - 1s 457ms/step - loss: 0.3579 - accuracy: 0.8516 - binary_io_u: 0.7376 - val_loss: 0.3669 - val_accuracy: 0.8475 - val_binary_io_u: 0.7348 - lr: 3.9062e-06
# Epoch 90/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3443 - accuracy: 0.8594 - binary_io_u: 0.7502
# Epoch 90:saving model to ./model_weight/callback_test/test_weight_epoch_090.h5
# 3/3 [==============================] - 2s 636ms/step - loss: 0.3443 - accuracy: 0.8594 - binary_io_u: 0.7502 - val_loss: 0.3663 - val_accuracy: 0.8476 - val_binary_io_u: 0.7349 - lr: 3.9062e-06
# Epoch 91/100
# 3/3 [==============================] - 1s 469ms/step - loss: 0.3473 - accuracy: 0.8571 - binary_io_u: 0.7471 - val_loss: 0.3658 - val_accuracy: 0.8477 - val_binary_io_u: 0.7350 - lr: 3.9062e-06
# Epoch 92/100
# 3/3 [==============================] - 1s 471ms/step - loss: 0.3370 - accuracy: 0.8635 - binary_io_u: 0.7570 - val_loss: 0.3654 - val_accuracy: 0.8477 - val_binary_io_u: 0.7351 - lr: 3.9062e-06
# Epoch 93/100
# 3/3 [==============================] - 1s 461ms/step - loss: 0.3557 - accuracy: 0.8508 - binary_io_u: 0.7375 - val_loss: 0.3649 - val_accuracy: 0.8478 - val_binary_io_u: 0.7351 - lr: 3.9062e-06
# Epoch 94/100
# 3/3 [==============================] - 2s 473ms/step - loss: 0.3507 - accuracy: 0.8528 - binary_io_u: 0.7405 - val_loss: 0.3645 - val_accuracy: 0.8478 - val_binary_io_u: 0.7351 - lr: 3.9062e-06
# Epoch 95/100
# 3/3 [==============================] - 1s 483ms/step - loss: 0.3472 - accuracy: 0.8569 - binary_io_u: 0.7480 - val_loss: 0.3641 - val_accuracy: 0.8478 - val_binary_io_u: 0.7351 - lr: 3.9062e-06
# Epoch 96/100
# 3/3 [==============================] - 1s 480ms/step - loss: 0.3394 - accuracy: 0.8612 - binary_io_u: 0.7536 - val_loss: 0.3637 - val_accuracy: 0.8478 - val_binary_io_u: 0.7352 - lr: 3.9062e-06
# Epoch 97/100
# 3/3 [==============================] - 2s 484ms/step - loss: 0.3353 - accuracy: 0.8629 - binary_io_u: 0.7548 - val_loss: 0.3632 - val_accuracy: 0.8480 - val_binary_io_u: 0.7354 - lr: 3.9062e-06
# Epoch 98/100
# 3/3 [==============================] - 2s 843ms/step - loss: 0.3362 - accuracy: 0.8634 - binary_io_u: 0.7566 - val_loss: 0.3629 - val_accuracy: 0.8480 - val_binary_io_u: 0.7354 - lr: 3.9062e-06
# Epoch 99/100
# 3/3 [==============================] - 1s 481ms/step - loss: 0.3415 - accuracy: 0.8613 - binary_io_u: 0.7529 - val_loss: 0.3626 - val_accuracy: 0.8480 - val_binary_io_u: 0.7355 - lr: 3.9062e-06
# Epoch 100/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3356 - accuracy: 0.8640 - binary_io_u: 0.7570
# Epoch 100:saving model to ./model_weight/callback_test/test_weight_epoch_100.h5
# 3/3 [==============================] - 2s 641ms/step - loss: 0.3356 - accuracy: 0.8640 - binary_io_u: 0.7570 - val_loss: 0.3622 - val_accuracy: 0.8481 - val_binary_io_u: 0.7356 - lr: 3.9062e-06

# %%
model.summary()
